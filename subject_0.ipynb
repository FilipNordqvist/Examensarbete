# %% [markdown]
# Example of how to parse the files and load data in dataframes.

# %%
import os
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib notebook

# %%
data_path = os.getcwd() + os.sep + 'data'
print(data_path)
# Out:
# /Users/filipnordqvist/Library/CloudStorage/OneDrive-Privat/Kurser/Examensarbete/data

# %%
# Loading data functions
def loader(data_path, blacklist):
    data = []
    all_data_csv = pd.read_csv(data_path + os.sep + 'metadata_tracks.csv')
    for name in os.listdir(data_path):
        if name != '.DS_Store' and 'csv' not in name and 'txt' not in name:
            print('---------------------------------------------')
            print("Loading walking data for subject: ",name)
            new_path = data_path + os.sep + name
            for name_in in os.listdir(new_path):
                if name_in != '.DS_Store' and name_in not in blacklist:
                    print("Loading test: ", name_in)
                    motion_csv = pd.read_csv(new_path + os.sep + name_in + os.sep + 'motion.csv')
                    position_csv = pd.read_csv(new_path + os.sep + name_in + os.sep + 'positions.csv')
                    orientation_csv = pd.read_csv(new_path + os.sep + name_in + os.sep + 'orientation.csv')
                    steps_csv = pd.read_csv(new_path + os.sep + name_in + os.sep + 'steps.csv')
                    event_csv = pd.read_csv(new_path + os.sep + name_in + os.sep + 'events.csv')

                    anon_test = walking_test(
                        name_in, event_csv,
                        motion_csv,
                        orientation_csv,
                        position_csv,
                        steps_csv
                    )
                    data.append(anon_test)

    return data, all_data_csv

class walking_test:
    def __init__(self, filename, events, motion, orientation, positions, steps): #
        self.filename = filename
        self.events = events
        self.motion = motion
        self.orientation = orientation
        self.positions = positions
        self.steps = steps

# %%
# Uploading metadata and determining blacklist
metadata = pd.read_csv(data_path + os.sep + 'metadata_tracks.csv')
print("Metadata columns: ", metadata.columns)
noIMU = metadata[metadata['hasMotion'] == False]['testName'].tolist()
noGPS = metadata[metadata['hasGNSS'] == False]['testName'].tolist()
blacklist = noIMU + noGPS
print("Blacklist: ", blacklist)
# Out:
# Metadata columns:  Index(['subject', 'testID', 'testName', 'isPatient', 'distanceReference',
#        'hasMotion', 'hasGNSS', 'device', 'distanceByApp', 'totSteps',
#        'path curvature', 'total_gaps_time_inertial', 'total_gaps_time_gnss',
#        'gt_type', 'country', 'gnss_anonimized', 'duration [s]', 'fs_acc',
#        'fs_gnss', 'fs_steps', 'average_walking_speed', 'smartphone_position',
#        'smartphone app'],
#       dtype='object')
# Blacklist:  ['0_0', '0_1', '0_2', '0_3', '0_4', '0_5', '0_6', '0_7', '0_8', '0_9', '0_10', '0_11', '0_12', '0_13', '0_14', '1_0', '1_1', '1_2', '1_3', '1_4', '1_5', '1_6', '1_7', '1_8', '1_9', '2_0', '2_1', '2_2', '2_3', '2_4', '2_5', '2_6', '2_7', '2_8', '2_9', '3_0', '3_5', '3_6', '3_7', '3_8', '3_9', '9_0', '9_1', '9_2', '9_3', '9_4', '9_5', '9_6', '9_7', '9_8', '9_9', '9_10', '15_0', '15_1', '15_2', '15_3', '15_4']

# %%
# Loading data
selection, info_all_tests = loader(data_path, blacklist=blacklist)
print("Successfully loaded data")
# Out:
# ---------------------------------------------
# Loading walking data for subject:  subject_12
# Loading test:  12_5
# Loading test:  12_2
# Loading test:  12_3
# Loading test:  12_4
# Loading test:  12_10
# Loading test:  12_11
# Loading test:  12_1
# Loading test:  12_6
# Loading test:  12_8
# Loading test:  12_9
# Loading test:  12_7
# Loading test:  12_0
# Loading test:  12_13
# Loading test:  12_12
# ---------------------------------------------
# Loading walking data for subject:  subject_15
# ---------------------------------------------
# Loading walking data for subject:  subject_14
# Loading test:  14_9
# Loading test:  14_0
# Loading test:  14_7
# Loading test:  14_6
# Loading test:  14_1
# Loading test:  14_8
# Loading test:  14_14
# Loading test:  14_13
# Loading test:  14_12
# Loading test:  14_4
# Loading test:  14_3
# Loading test:  14_2
# Loading test:  14_5
# Loading test:  14_10
# Loading test:  14_11
# ---------------------------------------------
# Loading walking data for subject:  subject_13
# Loading test:  13_11
# Loading test:  13_10
# Loading test:  13_8
# Loading test:  13_6
# Loading test:  13_1
# Loading test:  13_0
# Loading test:  13_7
# Loading test:  13_9
# Loading test:  13_12
# Loading test:  13_13
# Loading test:  13_2
# Loading test:  13_5
# Loading test:  13_4
# Loading test:  13_3
# ---------------------------------------------
# Loading walking data for subject:  subject_4
# Loading test:  4_2
# Loading test:  4_5
# Loading test:  4_4
# Loading test:  4_3
# Loading test:  4_6
# Loading test:  4_1
# Loading test:  4_8
# Loading test:  4_9
# Loading test:  4_0
# Loading test:  4_7
# ---------------------------------------------
# Loading walking data for subject:  subject_3
# Loading test:  3_4
# Loading test:  3_3
# Loading test:  3_2
# Loading test:  3_1
# ---------------------------------------------
# Loading walking data for subject:  subject_2
# ---------------------------------------------
# Loading walking data for subject:  subject_5
# Loading test:  5_8
# Loading test:  5_1
# Loading test:  5_6
# Loading test:  5_7
# Loading test:  5_0
# Loading test:  5_9
# Loading test:  5_5
# Loading test:  5_2
# Loading test:  5_3
# Loading test:  5_4
# ---------------------------------------------
# Loading walking data for subject:  subject_16
# Loading test:  16_3
# Loading test:  16_4
# Loading test:  16_2
# Loading test:  16_0
# Loading test:  16_1
# ---------------------------------------------
# Loading walking data for subject:  subject_11
# Loading test:  11_5
# Loading test:  11_2
# Loading test:  11_13
# Loading test:  11_14
# Loading test:  11_3
# Loading test:  11_4
# Loading test:  11_15
# Loading test:  11_12
# Loading test:  11_10
# Loading test:  11_1
# Loading test:  11_6
# Loading test:  11_8
# Loading test:  11_11
# Loading test:  11_9
# Loading test:  11_7
# Loading test:  11_0
# ---------------------------------------------
# Loading walking data for subject:  subject_18
# Loading test:  18_2
# Loading test:  18_3
# Loading test:  18_4
# Loading test:  18_1
# Loading test:  18_0
# ---------------------------------------------
# Loading walking data for subject:  subject_10
# Loading test:  10_8
# Loading test:  10_6
# Loading test:  10_1
# Loading test:  10_0
# Loading test:  10_7
# Loading test:  10_9
# Loading test:  10_15
# Loading test:  10_12
# Loading test:  10_13
# Loading test:  10_14
# Loading test:  10_2
# Loading test:  10_5
# Loading test:  10_4
# Loading test:  10_3
# Loading test:  10_11
# Loading test:  10_16
# Loading test:  10_17
# Loading test:  10_10
# ---------------------------------------------
# Loading walking data for subject:  subject_17
# Loading test:  17_0
# Loading test:  17_1
# Loading test:  17_4
# Loading test:  17_3
# Loading test:  17_2
# ---------------------------------------------
# Loading walking data for subject:  subject_0
# ---------------------------------------------
# Loading walking data for subject:  subject_7
# Loading test:  7_2
# Loading test:  7_5
# Loading test:  7_4
# Loading test:  7_3
# Loading test:  7_6
# Loading test:  7_1
# Loading test:  7_8
# Loading test:  7_9
# Loading test:  7_0
# Loading test:  7_7
# ---------------------------------------------
# Loading walking data for subject:  subject_9
# ---------------------------------------------
# Loading walking data for subject:  subject_8
# Loading test:  8_7
# Loading test:  8_0
# Loading test:  8_9
# Loading test:  8_8
# Loading test:  8_1
# Loading test:  8_6
# Loading test:  8_3
# Loading test:  8_4
# Loading test:  8_10
# Loading test:  8_5
# Loading test:  8_2
# ---------------------------------------------
# Loading walking data for subject:  subject_6
# Loading test:  6_8
# Loading test:  6_1
# Loading test:  6_6
# Loading test:  6_7
# Loading test:  6_0
# Loading test:  6_9
# Loading test:  6_5
# Loading test:  6_2
# Loading test:  6_3
# Loading test:  6_4
# ---------------------------------------------
# Loading walking data for subject:  subject_1
# Successfully loaded data

# %%
# Example of what a walking test contains:
print("Selection[0] contains: ")
print("Filename: ", selection[0].filename)
print("Events: ", selection[0].events.head())
print("Motion: ", selection[0].motion.head())
print("Orientation: ", selection[0].orientation.head())
print("Positions: ", selection[0].positions.head())
print("Steps: ", selection[0].steps.head())
# Out:
# Selection[0] contains:
# Filename:  12_5
# Events:     Unnamed: 0  signalStart  testStart        testEnd
# 0           0            0      961.0  241776.000023
# Motion:     Unnamed: 0     ms    accelX    accelY    accelZ  accelWithGX  accelWithGY  \
# 0           0  301.0  0.438315 -0.063984 -0.070899    -0.022308     1.661179
# 1           1  326.0  0.498090 -0.201496  0.016141    -0.035461     1.648026
# 2           2  344.0  0.458053 -0.219058 -0.166888    -0.171860     1.747330
# 3           3  366.0  0.212662 -0.051397 -0.305197    -0.256805     1.845428
# 4           4  383.0  0.212662 -0.051397 -0.305197    -0.429092     1.931564
#
#    accelWithGZ  rotRateAlpha  rotRateBeta  rotRateGamma  interval
# 0     9.639145      2.197900     3.448972      7.877995        16
# 1     9.442932      5.656489     1.173263      5.241214        16
# 2     9.349625      6.130341     0.611111      3.747971        16
# 3     9.267059      7.771335     2.842233      4.861783        16
# 4     9.143829      7.771335     2.842233      4.861783        16
# Orientation:     Unnamed: 0     ms    abs      alpha       beta     gamma
# 0           0  302.0  False  89.487328  10.918895  3.428223
# 1           1  327.0  False  89.647847  10.923407  3.264689
# 2           2  344.0  False  89.782477  10.939370  3.095456
# 3           3  366.0  False  89.958955  11.066507  2.847922
# 4           4  400.0  False  90.037391  11.195339  2.807798
# Positions:     Unnamed: 0      ms   latitude  longitude  altitude  confInterval  heading  \
# 0           0  -965.0  55.609194  12.994015        88            96      NaN
# 1           1    -4.0  55.609231  12.993989        82            11      NaN
# 2           2   961.0  55.609255  12.993972        83             9      NaN
# 3           3  1956.0  55.609268  12.993956        82             8      NaN
# 4           4  2970.0  55.609265  12.993948        79             7      NaN
#
#    speed
# 0    NaN
# 1    NaN
# 2    NaN
# 3    NaN
# 4    NaN
# Steps:     Unnamed: 0       ms  steps  floorsUp  floorsDown  distance  startDate  \
# 0           0    147.0      1       NaN         NaN       NaN     -217.0
# 1           1  13921.0      1       NaN         NaN       NaN     -217.0
# 2           2  14908.0      2       NaN         NaN       NaN     -217.0
# 3           3  14908.0      3       NaN         NaN       NaN     -217.0
# 4           4  15900.0      4       NaN         NaN       NaN     -217.0
#
#    endDate
# 0   -217.0
# 1  13783.0
# 2  14783.0
# 3  14783.0
# 4  15783.0

# %%
metadata[(metadata['subject'] == 12) & (metadata['testID'] == 5)]
# Out:
#      subject  testID testName  isPatient  distanceReference  hasMotion  \
# 133       12       5     12_5      False                296       True
#
#      hasGNSS             device  distanceByApp  totSteps  ...  gt_type  \
# 133     True  OnePlus ONE A2005     232.961828     416.0  ...    final
#
#      country  gnss_anonimized duration [s]     fs_acc   fs_gnss  fs_steps  \
# 133       SE            False          241  55.377593  1.008299   1.73029
#
#      average_walking_speed  smartphone_position  smartphone app
# 133               1.228216            hand held      Timed Walk
#
# [1 rows x 23 columns]
