# %% [markdown]
# # IMU - Thesis
#
# Filip and Gottfrid

# %% [markdown]
# ## 1.2 Reading Data from Files
#
# Read your data from the file into a DataFrame variable so that the column names correspond with
# the field names from the dataset. Print a list of all the column names.
#
# First we start of by importing all libraries needed for this assignment and defining paths for the files.

# %% [markdown]
# ### 1.2.1 Importing libraries

# %%
#@title
# Import all libraries needed for this tutorial

# Pandas: used to create and work with DataFrames
import pandas as pd #imports all of pandas library
from pandas import DataFrame, read_csv #imports some of the important functions from the pandas library.

# Scikit-learn: import preprocessing functions
from sklearn.preprocessing import LabelEncoder, label_binarize, OrdinalEncoder

from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler

# Matplotlib: used for data visualization/plotting
import matplotlib as mpl
import matplotlib.pyplot as plt
# Enable inline plotting, allows the plots to be seen in the notebook and stored with the document
# %matplotlib inline

# numpy
import numpy as np

# seaborn: used for heatmaps and other statistical plots
import seaborn as sns #might require installation with: conda install -c anaconda seaborn

# Importing statistical function for t-test from scipy
import scipy.stats as stats

# import KMeans
from sklearn.cluster import KMeans
# import nearest neighbors
#from sklearn.neighbors import NearestNeighbors

# Saving variables as files on disk
import pickle

import warnings
warnings.filterwarnings("ignore") #some warnings are supressed

# %% [markdown]
# #### 1.2.2.2 Using own computer

# %%
# If you are working on your own computer, change the working directory to the lab-1 folder
import os

# Print the current working directory
print("Current working directory:", os.getcwd())
# Out:
# Current working directory: /Users/filipnordqvist/Library/CloudStorage/OneDrive-Privat/Kurser/Examensarbete

# %%
#print("Current working directory:", os.getcwd())

# Opening and saving data to variables

# Saving raw data
file_path = 'data/metadata_tracks.csv' #path to the file
rawdata = pd.read_csv(file_path, sep=",", encoding='latin1')

print("Rawdata columns:", rawdata.columns)
# Out:
# Rawdata columns: Index(['subject', 'testID', 'testName', 'isPatient', 'distanceReference',
#        'hasMotion', 'hasGNSS', 'device', 'distanceByApp', 'totSteps',
#        'path curvature', 'total_gaps_time_inertial', 'total_gaps_time_gnss',
#        'gt_type', 'country', 'gnss_anonimized', 'duration [s]', 'fs_acc',
#        'fs_gnss', 'fs_steps', 'average_walking_speed', 'smartphone_position',
#        'smartphone app'],
#       dtype='object')

# %% [markdown]
# ### Looking at the data

# %%
rawdata.head()
# Out:
#    subject  testID testName  isPatient  distanceReference  hasMotion  hasGNSS  \
# 0        0       0      0_0       True                623      False     True
# 1        0       1      0_1       True                598      False     True
# 2        0       2      0_2       True                584      False     True
# 3        0       3      0_3       True                577      False     True
# 4        0       4      0_4       True                590      False     True
#
#              device  distanceByApp  totSteps  ...  gt_type  country  \
# 0  Apple iPhone11,8     598.373421     755.0  ...    final       UK
# 1  Apple iPhone11,8     587.334804     699.0  ...    final       UK
# 2  Apple iPhone11,8     577.005522     726.0  ...    final       UK
# 3  Apple iPhone11,8     539.365038     710.0  ...    final       UK
# 4  Apple iPhone11,8     566.744323     715.0  ...    final       UK
#
#    gnss_anonimized duration [s] fs_acc   fs_gnss  fs_steps  \
# 0             True          368    NaN  0.304348  0.380435
# 1             True          380    NaN  0.292105  0.357895
# 2             True          359    NaN  0.281337  0.381616
# 3             True          365    NaN  0.284932  0.372603
# 4             True          360    NaN  0.277778  0.375000
#
#    average_walking_speed  smartphone_position  smartphone app
# 0               1.692935            hand held      Timed Walk
# 1               1.573684            hand held      Timed Walk
# 2               1.626741            hand held      Timed Walk
# 3               1.580822            hand held      Timed Walk
# 4               1.638889            hand held      Timed Walk
#
# [5 rows x 23 columns]

# %%
rawdata.dtypes
# Out:
# subject                       int64
# testID                        int64
# testName                     object
# isPatient                      bool
# distanceReference             int64
# hasMotion                      bool
# hasGNSS                        bool
# device                       object
# distanceByApp               float64
# totSteps                    float64
# path curvature                int64
# total_gaps_time_inertial    float64
# total_gaps_time_gnss        float64
# gt_type                      object
# country                      object
# gnss_anonimized                bool
# duration [s]                  int64
# fs_acc                      float64
# fs_gnss                     float64
# fs_steps                    float64
# average_walking_speed       float64
# smartphone_position          object
# smartphone app               object
# dtype: object

# %%
rows, columns = rawdata.shape
print(f"The dataset has {rows} rows and {columns} columns.")
# Out:
# The dataset has 203 rows and 23 columns.

# %%
#@First and last phone used in the dataset
#Examples of addressing cells
print(rawdata.iloc[0,7], rawdata.iloc[202,7])
# Out:
# Apple iPhone11,8 OPPO CPH2247

# %%
# Get the unique smartphone positions
unique_positions = rawdata['smartphone_position'].unique().tolist()

# Count the number of unique positions
num_unique_positions = len(unique_positions)

print(f'There are {num_unique_positions} different types of smartphone positions.')
# Out:
# There are 1 different types of smartphone positions.

# %%
# Count the occurrences of True and False in the 'isPatient' column
patient_counts = rawdata['isPatient'].value_counts()

# Summary
summary = {
    'Is Patient': patient_counts[True],
    'Not Patient': patient_counts[False]
}

print(summary)
# Out:
# {'Is Patient': 75, 'Not Patient': 128}

# %%
rawdata['country'].value_counts()
# Out:
# country
# UK    106
# SE     97
# Name: count, dtype: int64

# %%
#@title
# Example: Listing all column names of rawdata. Observe the spaces in several of the names!
rawdata.columns
# Out:
# Index(['subject', 'testID', 'testName', 'isPatient', 'distanceReference',
#        'hasMotion', 'hasGNSS', 'device', 'distanceByApp', 'totSteps',
#        'path curvature', 'total_gaps_time_inertial', 'total_gaps_time_gnss',
#        'gt_type', 'country', 'gnss_anonimized', 'duration [s]', 'fs_acc',
#        'fs_gnss', 'fs_steps', 'average_walking_speed', 'smartphone_position',
#        'smartphone app'],
#       dtype='object')

# %%
#No swedish patients in the dataset
rawdata[(rawdata['isPatient'] == False) & (rawdata['country'] == 'SE')]
# Out:
#      subject  testID testName  isPatient  distanceReference  hasMotion  \
# 106       10       0     10_0      False                390       True
# 107       11       0     11_0      False                390       True
# 108       12       0     12_0      False                390       True
# 109       13       0     13_0      False                390       True
# 110       12       1     12_1      False                390       True
# ..       ...     ...      ...        ...                ...        ...
# 198       18       0     18_0      False                317       True
# 199       18       1     18_1      False                365       True
# 200       18       2     18_2      False                452       True
# 201       18       3     18_3      False                461       True
# 202       18       4     18_4      False                517       True
#
#      hasGNSS                 device  distanceByApp  totSteps  ...     gt_type  \
# 106     True           OPPO CPH2247     315.759852     600.0  ...       final
# 107     True           OPPO CPH2197     412.462362     649.0  ...       final
# 108     True         OnePlus AC2003     410.436432     593.0  ...       final
# 109     True  OnePlus ONEPLUS A5010     371.363988     627.0  ...       final
# 110     True      OnePlus ONE A2005     352.134130     613.0  ...       final
# ..       ...                    ...            ...       ...  ...         ...
# 198     True           OPPO CPH2247     314.359204     606.0  ...  continuous
# 199     True           OPPO CPH2247     366.678945     635.0  ...  continuous
# 200     True           OPPO CPH2247     462.021431     575.0  ...  continuous
# 201     True           OPPO CPH2247     474.967709     817.0  ...  continuous
# 202     True           OPPO CPH2247     502.632120     645.0  ...  continuous
#
#      country  gnss_anonimized duration [s]     fs_acc   fs_gnss  fs_steps  \
# 106       SE            False          360  59.755556  1.002778  0.922222
# 107       SE            False          364  59.195055  1.587912  0.989011
# 108       SE            False          363  59.217631  1.005510  1.617080
# 109       SE            False          361  59.653740  1.008310  0.947368
# 110       SE            False          361  56.307479  1.005540  1.700831
# ..       ...              ...          ...        ...       ...       ...
# 198       SE            False          361  59.759003  1.016620  1.432133
# 199       SE            False          361  59.842105  1.013850  1.457064
# 200       SE            False          361  59.800554  1.002770  0.903047
# 201       SE            False          361  59.822715  1.008310  1.166205
# 202       SE            False          361  59.786704  1.002770  0.941828
#
#      average_walking_speed  smartphone_position  smartphone app
# 106               1.083333            hand held      Timed Walk
# 107               1.071429            hand held      Timed Walk
# 108               1.074380            hand held      Timed Walk
# 109               1.080332            hand held      Timed Walk
# 110               1.080332            hand held      Timed Walk
# ..                     ...                  ...             ...
# 198               0.878116            hand held      Timed Walk
# 199               1.011080            hand held      Timed Walk
# 200               1.252078            hand held      Timed Walk
# 201               1.277008            hand held      Timed Walk
# 202               1.432133            hand held      Timed Walk
#
# [97 rows x 23 columns]

# %%
#Finding missing values in the original data
rawdata.isnull().sum()
# Out:
# subject                      0
# testID                       0
# testName                     0
# isPatient                    0
# distanceReference            0
# hasMotion                    0
# hasGNSS                      0
# device                       0
# distanceByApp                5
# totSteps                     5
# path curvature               0
# total_gaps_time_inertial    52
# total_gaps_time_gnss         5
# gt_type                      0
# country                      0
# gnss_anonimized              0
# duration [s]                 0
# fs_acc                      52
# fs_gnss                      5
# fs_steps                     5
# average_walking_speed        0
# smartphone_position          0
# smartphone app               0
# dtype: int64
