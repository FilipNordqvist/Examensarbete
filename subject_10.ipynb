# %% [markdown]
# Example of how to parse the files and load data in dataframes.

# %%
import os
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib
import numpy as np
matplotlib.use('TkAgg')
# %matplotlib notebook
# %matplotlib inline

# %%
data_path = os.getcwd() + os.sep + 'data'
print(data_path)
# Out:
# C:\Users\Filip\OneDrive\Documents\GitHub\Examensarbete\data

# %%
# Loading data functions
def loader(data_path, blacklist):
    data = []
    all_data_csv = pd.read_csv(data_path + os.sep + 'metadata_tracks.csv')
    for name in os.listdir(data_path):
        if name != '.DS_Store' and 'csv' not in name and 'txt' not in name:
            print('---------------------------------------------')
            print("Loading walking data for subject: ",name)
            new_path = data_path + os.sep + name
            for name_in in os.listdir(new_path):
                if name_in != '.DS_Store' and name_in not in blacklist:
                    print("Loading test: ", name_in)
                    motion_csv = pd.read_csv(new_path + os.sep + name_in + os.sep + 'motion.csv')
                    position_csv = pd.read_csv(new_path + os.sep + name_in + os.sep + 'positions.csv')
                    orientation_csv = pd.read_csv(new_path + os.sep + name_in + os.sep + 'orientation.csv')
                    steps_csv = pd.read_csv(new_path + os.sep + name_in + os.sep + 'steps.csv')
                    event_csv = pd.read_csv(new_path + os.sep + name_in + os.sep + 'events.csv')

                    anon_test = walking_test(
                        name_in, event_csv,
                        motion_csv,
                        orientation_csv,
                        position_csv,
                        steps_csv
                    )
                    data.append(anon_test)

    return data, all_data_csv

class walking_test:
    def __init__(self, filename, events, motion, orientation, positions, steps): #
        self.filename = filename
        self.events = events
        self.motion = motion
        self.orientation = orientation
        self.positions = positions
        self.steps = steps

# %%
# Uploading metadata and determining blacklist
metadata = pd.read_csv(data_path + os.sep + 'metadata_tracks.csv')
print("Metadata columns: ", metadata.columns)
noIMU = metadata[metadata['hasMotion'] == False]['testName'].tolist()
noGPS = metadata[metadata['hasGNSS'] == False]['testName'].tolist()
blacklist = noIMU + noGPS
print("Blacklist: ", blacklist)
# Out:
# Metadata columns:  Index(['subject', 'testID', 'testName', 'isPatient', 'distanceReference',
#        'hasMotion', 'hasGNSS', 'device', 'distanceByApp', 'totSteps',
#        'path curvature', 'total_gaps_time_inertial', 'total_gaps_time_gnss',
#        'gt_type', 'country', 'gnss_anonimized', 'duration [s]', 'fs_acc',
#        'fs_gnss', 'fs_steps', 'average_walking_speed', 'smartphone_position',
#        'smartphone app'],
#       dtype='object')
# Blacklist:  ['0_0', '0_1', '0_2', '0_3', '0_4', '0_5', '0_6', '0_7', '0_8', '0_9', '0_10', '0_11', '0_12', '0_13', '0_14', '1_0', '1_1', '1_2', '1_3', '1_4', '1_5', '1_6', '1_7', '1_8', '1_9', '2_0', '2_1', '2_2', '2_3', '2_4', '2_5', '2_6', '2_7', '2_8', '2_9', '3_0', '3_5', '3_6', '3_7', '3_8', '3_9', '9_0', '9_1', '9_2', '9_3', '9_4', '9_5', '9_6', '9_7', '9_8', '9_9', '9_10', '15_0', '15_1', '15_2', '15_3', '15_4']

# %%
kolla = metadata['testName'].tolist()
print("All tests: ", kolla)
# Out:
# All tests:  ['0_0', '0_1', '0_2', '0_3', '0_4', '0_5', '0_6', '0_7', '0_8', '0_9', '0_10', '0_11', '0_12', '0_13', '0_14', '1_0', '1_1', '1_2', '1_3', '1_4', '1_5', '1_6', '1_7', '1_8', '1_9', '2_0', '2_1', '2_2', '2_3', '2_4', '2_5', '2_6', '2_7', '2_8', '2_9', '3_0', '3_1', '3_2', '3_3', '3_4', '3_5', '3_6', '3_7', '3_8', '3_9', '4_0', '4_1', '4_2', '4_3', '4_4', '4_5', '4_6', '4_7', '4_8', '4_9', '5_0', '5_1', '5_2', '5_3', '5_4', '5_5', '5_6', '5_7', '5_8', '5_9', '6_0', '6_1', '6_2', '6_3', '6_4', '6_5', '6_6', '6_7', '6_8', '6_9', '7_0', '7_1', '7_2', '7_3', '7_4', '7_5', '7_6', '7_7', '7_8', '7_9', '8_0', '8_1', '8_2', '8_3', '8_4', '8_5', '8_6', '8_7', '8_8', '8_9', '9_0', '9_1', '9_2', '9_3', '9_4', '9_5', '9_6', '9_7', '9_8', '9_9', '9_10', '10_0', '11_0', '12_0', '13_0', '12_1', '10_1', '13_1', '11_1', '10_2', '11_2', '12_2', '13_2', '12_3', '10_3', '13_3', '11_3', '10_4', '10_5', '11_4', '10_6', '11_5', '10_7', '10_8', '11_6', '12_4', '13_4', '13_5', '12_5', '10_9', '11_7', '10_10', '11_8', '12_6', '13_6', '13_7', '12_7', '10_11', '11_9', '10_12', '11_10', '12_8', '13_8', '13_9', '12_9', '10_13', '11_11', '10_14', '11_12', '12_10', '13_10', '13_11', '12_11', '10_15', '11_13', '10_16', '11_14', '12_12', '13_12', '12_13', '10_17', '13_13', '11_15', '14_0', '14_1', '14_2', '14_3', '14_4', '14_5', '14_6', '14_7', '14_8', '14_9', '14_10', '14_11', '14_12', '14_13', '14_14', '15_0', '15_1', '15_2', '15_3', '15_4', '16_0', '16_1', '16_2', '16_3', '16_4', '17_0', '17_1', '17_2', '17_3', '17_4', '18_0', '18_1', '18_2', '18_3', '18_4']

# %%
# Loading data
selection, info_all_tests = loader(data_path, blacklist=blacklist)
print("Successfully loaded data")
# Out:
# ---------------------------------------------
# Loading walking data for subject:  subject_0
# ---------------------------------------------
# Loading walking data for subject:  subject_1
# ---------------------------------------------
# Loading walking data for subject:  subject_10
# Loading test:  10_0
# Loading test:  10_1
# Loading test:  10_10
# Loading test:  10_11
# Loading test:  10_12
# Loading test:  10_13
# Loading test:  10_14
# Loading test:  10_15
# Loading test:  10_16
# Loading test:  10_17
# Loading test:  10_2
# Loading test:  10_3
# Loading test:  10_4
# Loading test:  10_5
# Loading test:  10_6
# Loading test:  10_7
# Loading test:  10_8
# Loading test:  10_9
# ---------------------------------------------
# Loading walking data for subject:  subject_11
# Loading test:  11_0
# Loading test:  11_1
# Loading test:  11_10
# Loading test:  11_11
# Loading test:  11_12
# Loading test:  11_13
# Loading test:  11_14
# Loading test:  11_15
# Loading test:  11_2
# Loading test:  11_3
# Loading test:  11_4
# Loading test:  11_5
# Loading test:  11_6
# Loading test:  11_7
# Loading test:  11_8
# Loading test:  11_9
# ---------------------------------------------
# Loading walking data for subject:  subject_12
# Loading test:  12_0
# Loading test:  12_1
# Loading test:  12_10
# Loading test:  12_11
# Loading test:  12_12
# Loading test:  12_13
# Loading test:  12_2
# Loading test:  12_3
# Loading test:  12_4
# Loading test:  12_5
# Loading test:  12_6
# Loading test:  12_7
# Loading test:  12_8
# Loading test:  12_9
# ---------------------------------------------
# Loading walking data for subject:  subject_13
# Loading test:  13_0
# Loading test:  13_1
# Loading test:  13_10
# Loading test:  13_11
# Loading test:  13_12
# Loading test:  13_13
# Loading test:  13_2
# Loading test:  13_3
# Loading test:  13_4
# Loading test:  13_5
# Loading test:  13_6
# Loading test:  13_7
# Loading test:  13_8
# Loading test:  13_9
# ---------------------------------------------
# Loading walking data for subject:  subject_14
# Loading test:  14_0
# Loading test:  14_1
# Loading test:  14_10
# Loading test:  14_11
# Loading test:  14_12
# Loading test:  14_13
# Loading test:  14_14
# Loading test:  14_2
# Loading test:  14_3
# Loading test:  14_4
# Loading test:  14_5
# Loading test:  14_6
# Loading test:  14_7
# Loading test:  14_8
# Loading test:  14_9
# ---------------------------------------------
# Loading walking data for subject:  subject_15
# ---------------------------------------------
# Loading walking data for subject:  subject_16
# Loading test:  16_0
# Loading test:  16_1
# Loading test:  16_2
# Loading test:  16_3
# Loading test:  16_4
# ---------------------------------------------
# Loading walking data for subject:  subject_17
# Loading test:  17_0
# Loading test:  17_1
# Loading test:  17_2
# Loading test:  17_3
# Loading test:  17_4
# ---------------------------------------------
# Loading walking data for subject:  subject_18
# Loading test:  18_0
# Loading test:  18_1
# Loading test:  18_2
# Loading test:  18_3
# Loading test:  18_4
# ---------------------------------------------
# Loading walking data for subject:  subject_2
# ---------------------------------------------
# Loading walking data for subject:  subject_3
# Loading test:  3_1
# Loading test:  3_2
# Loading test:  3_3
# Loading test:  3_4
# ---------------------------------------------
# Loading walking data for subject:  subject_4
# Loading test:  4_0
# Loading test:  4_1
# Loading test:  4_2
# Loading test:  4_3
# Loading test:  4_4
# Loading test:  4_5
# Loading test:  4_6
# Loading test:  4_7
# Loading test:  4_8
# Loading test:  4_9
# ---------------------------------------------
# Loading walking data for subject:  subject_5
# Loading test:  5_0
# Loading test:  5_1
# Loading test:  5_2
# Loading test:  5_3
# Loading test:  5_4
# Loading test:  5_5
# Loading test:  5_6
# Loading test:  5_7
# Loading test:  5_8
# Loading test:  5_9
# ---------------------------------------------
# Loading walking data for subject:  subject_6
# Loading test:  6_0
# Loading test:  6_1
# Loading test:  6_2
# Loading test:  6_3
# Loading test:  6_4
# Loading test:  6_5
# Loading test:  6_6
# Loading test:  6_7
# Loading test:  6_8
# Loading test:  6_9
# ---------------------------------------------
# Loading walking data for subject:  subject_7
# Loading test:  7_0
# Loading test:  7_1
# Loading test:  7_2
# Loading test:  7_3
# Loading test:  7_4
# Loading test:  7_5
# Loading test:  7_6
# Loading test:  7_7
# Loading test:  7_8
# Loading test:  7_9
# ---------------------------------------------
# Loading walking data for subject:  subject_8
# Loading test:  8_0
# Loading test:  8_1
# Loading test:  8_10
# Loading test:  8_2
# Loading test:  8_3
# Loading test:  8_4
# Loading test:  8_5
# Loading test:  8_6
# Loading test:  8_7
# Loading test:  8_8
# Loading test:  8_9
# ---------------------------------------------
# Loading walking data for subject:  subject_9
# Successfully loaded data

# %%
# Example of what a walking test contains:
print("Selection[0] contains: ")
print("Filename: ", selection[35].filename)
print("Events: ", selection[35].events.head())
print("Motion: ", selection[35].motion.head())
print("Orientation: ", selection[35].orientation.head())
print("Positions: ", selection[35].positions.head())
print("Steps: ", selection[30].steps.head())
# Out:
# Selection[0] contains:
# Filename:  12_1
# Events:     Unnamed: 0  signalStart  testStart        testEnd
# 0           0            0      983.0  361777.999878
# Motion:     Unnamed: 0     ms    accelX    accelY    accelZ  accelWithGX  accelWithGY  \
# 0           0  289.0  0.205545 -0.053216 -0.250170    -0.759293     3.188995
# 1           1  306.0  0.119400 -0.064816 -0.387579    -0.624100     3.129181
# 2           2  324.0  0.119400 -0.064816 -0.387579    -0.716232     3.112427
# 3           3  340.0  0.125456 -0.084980 -0.279691    -0.773651     3.005951
# 4           4  360.0  0.061552 -0.161709  0.092924    -0.773651     3.005951
#
#    accelWithGZ  rotRateAlpha  rotRateBeta  rotRateGamma  interval
# 0     8.847122     -5.926637    -1.862183      1.842949        16
# 1     8.492981     -6.569221    -2.220631      2.451437        16
# 2     8.911728     -6.569221    -2.220631      2.451437        16
# 3     9.296982     -9.896671    -0.808694      1.891033        16
# 4     9.296982     -5.904780     0.000000      2.327291        16
# Orientation:     Unnamed: 0     ms    abs      alpha       beta     gamma
# 0           0  293.0  False  88.135553  19.484160  5.646571
# 1           1  309.0  False  88.203973  19.402604  5.519559
# 2           2  343.0  False  88.338995  19.256277  5.313678
# 3           3  360.0  False  88.402403  19.107070  5.232168
# 4           4  380.0  False  88.460097  18.919193  5.184985
# Positions:     Unnamed: 0      ms   latitude  longitude  altitude  confInterval  heading  \
# 0           0  -972.0  55.608179  12.990424        51          16.0      NaN
# 1           1    -5.0  55.608177  12.990423        52          10.0      NaN
# 2           2   983.0  55.608176  12.990416        52           8.0      NaN
# 3           3  1983.0  55.608177  12.990409        52           6.0      NaN
# 4           4  2986.0  55.608178  12.990405        54           5.0      NaN
#
#    speed  time_s  distance_m  speed_kmph  speed_mps
# 0    NaN   0.000    0.000000    0.000000   0.000000
# 1    NaN   0.967    0.169197    0.629896   0.174971
# 2    NaN   1.955    0.432204    1.574832   0.437453
# 3    NaN   2.955    0.442413    1.592688   0.442413
# 4    NaN   3.958    0.319536    1.146890   0.318581
# Steps:     Unnamed: 0       ms  steps  floorsUp  floorsDown  distance  startDate  \
# 0           0    386.0      1       NaN         NaN       NaN       24.0
# 1           1  18621.0      1       NaN         NaN       NaN       24.0
# 2           2  20611.0      3       NaN         NaN       NaN       24.0
# 3           3  20612.0      5       NaN         NaN       NaN       24.0
# 4           4  22591.0      7       NaN         NaN       NaN       24.0
#
#    endDate
# 0     24.0
# 1  18024.0
# 2  20024.0
# 3  20024.0
# 4  22024.0

# %%
def calculate_motion_magnitude(test):
    """Beräknar rörelsens magnitud från accelerometer och GPS"""
    
    # **1. Rörelse från accelerometerdata**
    test.motion["accel_magnitude"] = np.sqrt(
        test.motion["accelX"]**2 + test.motion["accelY"]**2 + test.motion["accelZ"]**2
    )

    # **2. Rörelse från GPS-data**
    distances = [0]  # Startvärde för första punkten
    for i in range(1, len(test.positions)):
        prev = (test.positions.loc[i - 1, "latitude"], test.positions.loc[i - 1, "longitude"])
        curr = (test.positions.loc[i, "latitude"], test.positions.loc[i, "longitude"])
        distances.append(geodesic(prev, curr).meters)

    test.positions["distance_m"] = distances
# Out:
#      subject  testID testName  isPatient  distanceReference  hasMotion  \
# 106       10       0     10_0      False                390       True
#
#      hasGNSS        device  distanceByApp  totSteps  ...  gt_type  country  \
# 106     True  OPPO CPH2247     315.759852     600.0  ...    final       SE
#
#      gnss_anonimized duration [s]     fs_acc   fs_gnss  fs_steps  \
# 106            False          360  59.755556  1.002778  0.922222
#
#      average_walking_speed  smartphone_position  smartphone app
# 106               1.083333            hand held      Timed Walk
#
# [1 rows x 23 columns]
